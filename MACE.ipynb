# %% [markdown]
# <a href="https://colab.research.google.com/github/snehadharma/MACE_Model/blob/main/MACE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/imagdau/Tutorials.git
# !pip install xtb nglview ipywidgets rdkit x3dase
# !pip install git+https://github.com/imagdau/aseMolec@main
# !pip install git+https://github.com/acesuit/mace@develop
# %cd Tutorials
# Out:
# Cloning into 'Tutorials'...
# remote: Enumerating objects: 350, done.
# remote: Counting objects: 100% (120/120), done.
# remote: Compressing objects: 100% (85/85), done.
# remote: Total 350 (delta 58), reused 93 (delta 35), pack-reused 230 (from 1)
# Receiving objects: 100% (350/350), 34.19 MiB | 21.62 MiB/s, done.
# Resolving deltas: 100% (166/166), done.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.9/21.9 MB 37.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 76.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 15.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.2/34.2 MB 25.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.4/849.4 kB 55.4 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/BingqingCheng/ab-initio-thermodynamics-of-water.git
# %cd ab-initio-thermodynamics-of-water
# Out:
# Cloning into 'ab-initio-thermodynamics-of-water'...
# remote: Enumerating objects: 105, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 105 (delta 0), reused 0 (delta 0), pack-reused 100 (from 1)
# Receiving objects: 100% (105/105), 24.73 MiB | 16.94 MiB/s, done.
# Resolving deltas: 100% (26/26), done.
# /content/Tutorials/ab-initio-thermodynamics-of-water

# %%
from ase.io import read, write
import numpy as np

db = read('training-set/dataset_1593.xyz', ':') #read in list of configs

print("Number of configs in database: ", len(db))
print("Number of atoms in each config: ", np.array([len(at) for at in db]))
print("Number of atoms in the smallest config: ", np.min([len(at) for at in db])) #test if database contains isolated atoms
print("Information stored in config.info: \n", db[10].info) #check info
print("Information stored in config.arrays: \n", db[10].arrays)
# Out:
# Number of configs in database:  1593
# Number of atoms in each config:  [192 192 192 ... 192 192 192]
# Number of atoms in the smallest config:  192
# Information stored in config.info:
#  {'TotEnergy': -1103.68636, 'cutoff': -1.0, 'nneightol': 1.2}
# Information stored in config.arrays:
#  {'numbers': array([8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8,
#        1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1,
#        1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1,
#        8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8,
#        1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1,
#        1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1,
#        8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8,
#        1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1,
# ...

# %%
from ase.io import read, write
import numpy as np
from aseMolec import anaAtoms as aa
from matplotlib import pyplot as plt

db = read('training-set/dataset_1593.xyz', ':') #read in list of configs

print("Number of configs in database: ", len(db))
print("Number of atoms in each config: ", np.array([len(at) for at in db]))
print("Number of atoms in the smallest config: ", np.min([len(at) for at in db])) #test if database contains isolated atoms
print("Information stored in config.info: \n", db[10].info) #check info
print("Information stored in config.arrays: \n", db[10].arrays)
# Out:
# Number of configs in database:  1593
# Number of atoms in each config:  [192 192 192 ... 192 192 192]
# Number of atoms in the smallest config:  192
# Information stored in config.info:
#  {'TotEnergy': -1103.68636, 'cutoff': -1.0, 'nneightol': 1.2}
# Information stored in config.arrays:
#  {'numbers': array([8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8,
#        1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1,
#        1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1,
#        8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8,
#        1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1,
#        1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1,
#        8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8,
#        1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1,
# ...

# %%
# Apply aa.wrap_molecs to the entire db list
aa.wrap_molecs(db, prog=False) #identify molecules and label molecular clusters for all frames

# write('data/solvent_molecs.xyz', db) #save full result
print("Information stored in config.info: \n", db[10].info)
print("Information stored in config.arrays: \n", db[10].arrays)
# Out:
# Information stored in config.info:
#  {'TotEnergy': -1103.68636, 'cutoff': -1.0, 'nneightol': 1.2, 'Nmols': 191, 'Comp': 'H(127):O(63)---UNK_HO(1)'}
# Information stored in config.arrays:
#  {'numbers': array([8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8,
#        1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1,
#        1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1,
#        8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8,
#        1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1,
#        1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1,
#        8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8,
#        1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1,
#        1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1, 8, 1, 1]), 'positions': array([[21.0266  , 22.424   ,  6.5011  ],
#        [20.624701,  0.211   ,  5.4435  ],
# ...

# %%
# Now, 'Nmols' should be available for all Atoms objects in db
Nmols = np.array([at.info['Nmols'] for at in db]) #collect Nmols information across all data
plt.hist(Nmols, align='left', bins=[1,2,3,4,5,6,7], rwidth=0.8);
plt.xlabel('# Molecs');
plt.ylabel('# Configs comprising that # Molecs');
